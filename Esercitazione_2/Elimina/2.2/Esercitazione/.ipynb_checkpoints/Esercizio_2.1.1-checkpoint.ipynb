# %% [markdown]
# ESERCIZIO 1.1 RISULTATI

# %%
file=open("Vettore_media.dat", "r")


contenuto=file.read()
righe=contenuto.split("\n")
ave_progr=[]
error_progr=[]
for riga in righe[:-1]:
    elementi=riga.split("  ")
#    print(elementi)
    ave_progr.append(float(elementi[1]))
    error_progr.append(float(elementi[2]))
    
#somma=[elemento[1] for riga in righe for elemento in riga]
#print(colonna)
file.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-b989628243af> in <module>
#       9     elementi=riga.split("\t")
#      10 #    print(elementi)
# ---> 11     ave_progr.append(float(elementi[1]))
#      12     error_progr.append(float(elementi[2]))
#      13
#
# IndexError: list index out of range

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

N=100
#M=100000
f=np.asfarray(ave_progr)
x=np.arange(N)
#x*=int(N)


plt.errorbar(x, f, yerr=error_progr)

plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()
